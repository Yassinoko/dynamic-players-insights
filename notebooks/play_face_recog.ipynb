# %% [markdown]
# ## Playing with Face-recog lib

# %% [markdown]
# #### Importing packages

# %%
import face_recognition
import matplotlib.pyplot as plt

# %% [markdown]
# #### Test on sample data from faces folder

# %%
alaba_image_1 = face_recognition.load_image_file("notebooks/Alaba Real Madrid_0.jpg")
alaba_image_2 = face_recognition.load_image_file("notebooks/Alaba Real Madrid_26.jpg")
choupa_image_1 = face_recognition.load_image_file("notebooks/Choupo-Moting Bayern_2.jpg")
choupa_image_2 = face_recognition.load_image_file("notebooks/Choupo-Moting Bayern_28.jpg")

alaba_encoding_1 = face_recognition.face_encodings(alaba_image_1)[0]
alaba_encoding_2 = face_recognition.face_encodings(alaba_image_2)[0]
choupa_encoding_1 = face_recognition.face_encodings(choupa_image_1)[0]
choupa_encoding_2 = face_recognition.face_encodings(choupa_image_2)[0]

results = face_recognition.compare_faces([alaba_encoding_1], choupa_encoding_2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 alaba_image_1 = face_recognition.load_image_file("notebooks/Alaba Real Madrid_0.jpg")
#       2 alaba_image_2 = face_recognition.load_image_file("notebooks/Alaba Real Madrid_26.jpg")
#       3 choupa_image_1 = face_recognition.load_image_file("notebooks/Choupo-Moting Bayern_2.jpg")
#
# File ~/.pyenv/versions/3.10.6/envs/dynamic-players-insights/lib/python3.10/site-packages/face_recognition/api.py:86, in load_image_file(file, mode)
#      78 def load_image_file(file, mode='RGB'):
#      79     """
#      80     Loads an image file (.jpg, .png, etc) into a numpy array
#      81
#    (...)
#      84     :return: image contents as numpy array
#      85     """
# ---> 86     im = PIL.Image.open(file)
#      87     if mode:
#      88         im = im.convert(mode)
#
# ...

# %%
results

# %%
alaba_encoding_1

# %%
image = face_recognition.load_image_file("../raw_data/faces/Alaba Real Madrid/Alaba Real Madrid_12.jpg")
face_locations = face_recognition.face_locations(image)

# %%
image
# Out:
# array([[[  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1],
#         ...,
#         [ 13,   3,   2],
#         [ 13,   3,   2],
#         [ 13,   3,   2]],
#
#        [[  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1],
#         ...,
#         [ 13,   3,   2],
#         [ 13,   3,   2],
#         [ 13,   3,   2]],
#
#        [[  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1],
#         ...,
#         [ 13,   3,   2],
#         [ 13,   3,   2],
#         [ 13,   3,   2]],
#
#        ...,
#
#        [[117,  61,  36],
#         [120,  64,  37],
#         [126,  69,  40],
#         ...,
#         [ 16,  18,  15],
#         [ 16,  18,  15],
#         [ 16,  18,  15]],
#
#        [[123,  66,  37],
#         [127,  70,  41],
#         [133,  74,  44],
#         ...,
#         [ 16,  18,  15],
#         [ 16,  18,  15],
#         [ 16,  18,  15]],
#
#        [[127,  70,  41],
#         [132,  73,  43],
#         [137,  76,  45],
# ...

# %%
face_locations

# %%
image[199:307, 270:378].shape
# Out:
# (108, 108, 3)

# %%
plt.imshow(image[199:307, 270:378])

# %%
image = face_recognition.load_image_file("../raw_data/faces/Alaba Real Madrid/Alaba Real Madrid_16.jpg")
face_locations = face_recognition.face_locations(image)
face_locations
# Out:
# [(68, 354, 175, 247)]

# %%
image[96:225, 253:382].shape
# Out:
# (129, 129, 3)

# %%
plt.imshow(image[96:225, 253:382])
